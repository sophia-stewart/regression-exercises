# %% [markdown]
# # Scaling Exercises
# ---
# Do your work for these exercises in a jupyter notebook named `scaling`. Use the telco dataset you acquired and prepped in previous lesson.
#
# ### 1. Apply the scalers we talked about in this lesson to your data and visualize the results for the unscaled and scaled distribution.

# %%
import matplotlib.pyplot as plt
import sklearn.preprocessing
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import pydataset
import seaborn as sns
import prepare

# %%
# retrieve telco data
train, validate, test = prepare.wrangle_telco()
train.shape, validate.shape, test.shape
# Out:
# ((3925, 32), (1683, 32), (1402, 32))

# %%
# view distributions of data to be scaled
plt.subplot(1, 2, 1)
plt.title('monthly_charges')
train.monthly_charges.hist()
plt.subplot(1, 2, 2)
plt.title('total_charges')
train.total_charges.hist()
plt.suptitle('Unscaled Data')
plt.tight_layout();

# %% [markdown]
# #### Min-Max Scaling

# %%
# create object
mm_scaler = sklearn.preprocessing.MinMaxScaler()
# fit object
mm_scaler.fit(train[['total_charges', 'monthly_charges']])
# transform (use) object
scaled_data = mm_scaler.transform(train[['total_charges', 'monthly_charges']])
# create new columns of scaled data
train[['total_charges_scaled', 'monthly_charges_scaled']] = scaled_data
# visualize new and old distributions
plt.subplot(1, 2, 1)
train.total_charges.hist()
plt.title('Before Scaling')
plt.subplot(1, 2, 2)
train.total_charges_scaled.hist()
plt.title('After Scaling')
plt.suptitle('total_charges')
plt.tight_layout();

# %%
plt.subplot(1, 2, 1)
train.monthly_charges.hist()
plt.title('Before Scaling')
plt.subplot(1, 2, 2)
train.monthly_charges_scaled.hist()
plt.title('After Scaling')
plt.suptitle('monthly_charges')
plt.tight_layout();

# %% [markdown]
# #### Standard Scaling

# %%
# create object
s_scaler = sklearn.preprocessing.StandardScaler()
# fit object
s_scaler.fit(train[['total_charges', 'monthly_charges']])
# transform object
train[['total_charges_scaled', 'monthly_charges_scaled']] = s_scaler.transform(train[['total_charges', 'monthly_charges']])
# visualize distributions
plt.subplot(1, 2, 1)
train.total_charges.hist()
plt.title('Before Scaling')
plt.subplot(1, 2, 2)
train.total_charges_scaled.hist()
plt.title('After Scaling')
plt.suptitle('total_charges')
plt.tight_layout();

# %%
plt.subplot(1, 2, 1)
train.monthly_charges.hist()
plt.title('Before Scaling')
plt.subplot(1, 2, 2)
train.monthly_charges_scaled.hist()
plt.title('After Scaling')
plt.suptitle('monthly_charges')
plt.tight_layout();

# %% [markdown]
# #### Robust Scaling

# %%
# create object
r_scaler = sklearn.preprocessing.RobustScaler()
# fit object
r_scaler.fit(train[['total_charges', 'monthly_charges']])
# transform object
train[['total_charges_scaled', 'monthly_charges_scaled']] = r_scaler.transform(train[['total_charges', 'monthly_charges']])
# visualize distributions
plt.subplot(1, 2, 1)
train.total_charges.hist()
plt.title('Before Scaling')
plt.subplot(1, 2, 2)
train.total_charges_scaled.hist()
plt.title('After Scaling')
plt.suptitle('total_charges')
plt.tight_layout();

# %%
plt.subplot(1, 2, 1)
train.monthly_charges.hist()
plt.title('Before Scaling')
plt.subplot(1, 2, 2)
train.monthly_charges_scaled.hist()
plt.title('After Scaling')
plt.suptitle('monthly_charges')
plt.tight_layout();

# %% [markdown]
# ### 2. Apply the `.inverse_transform` method to your scaled data. Is the resulting dataset the exact same as the original data?
#
# #### Min-Max

# %%
# get min-max scaled values
train[['total_charges_scaled', 'monthly_charges_scaled']] = mm_scaler.transform(train[['total_charges', 'monthly_charges']])
# inverse transform values
train[['total_charges_inverse', 'monthly_charges_inverse']] = mm_scaler.inverse_transform(train[['total_charges_scaled', 'monthly_charges_scaled']])
# visualize distributions
train[['total_charges_inverse', 'total_charges', 'monthly_charges_inverse', 'monthly_charges']].hist()
plt.tight_layout()
# view summary stats
train[['total_charges_inverse', 'total_charges', 'monthly_charges_inverse', 'monthly_charges']].describe().T
# Out:
#                           count         mean          std    min     25%  \
# total_charges_inverse    3925.0  2256.819223  2253.998263  18.85  392.65
# total_charges            3925.0  2256.819223  2253.998263  18.85  392.65
# monthly_charges_inverse  3925.0    64.722904    29.852930  18.25   37.70
# monthly_charges          3925.0    64.722904    29.852930  18.25   37.70
#
#                              50%      75%      max
# total_charges_inverse    1372.45  3729.75  8684.80
# total_charges            1372.45  3729.75  8684.80
# monthly_charges_inverse    70.15    89.70   118.75
# monthly_charges            70.15    89.70   118.75

# %%
# get standard scaled values
train[['total_charges_scaled', 'monthly_charges_scaled']] = s_scaler.transform(train[['total_charges', 'monthly_charges']])
# inverse transform
train[['total_charges_inverse', 'monthly_charges_inverse']] = s_scaler.inverse_transform(train[['total_charges_scaled', 'monthly_charges_scaled']])
# visualize distributions
train[['total_charges_inverse', 'total_charges', 'monthly_charges_inverse', 'monthly_charges']].hist()
plt.tight_layout()
# view summary stats
train[['total_charges_inverse', 'total_charges', 'monthly_charges_inverse', 'monthly_charges']].describe().T
# Out:
#                           count         mean          std    min     25%  \
# total_charges_inverse    3925.0  2256.819223  2253.998263  18.85  392.65
# total_charges            3925.0  2256.819223  2253.998263  18.85  392.65
# monthly_charges_inverse  3925.0    64.722904    29.852930  18.25   37.70
# monthly_charges          3925.0    64.722904    29.852930  18.25   37.70
#
#                              50%      75%      max
# total_charges_inverse    1372.45  3729.75  8684.80
# total_charges            1372.45  3729.75  8684.80
# monthly_charges_inverse    70.15    89.70   118.75
# monthly_charges            70.15    89.70   118.75

# %%
# get robust scaled values
train[['total_charges_scaled', 'monthly_charges_scaled']] = r_scaler.transform(train[['total_charges', 'monthly_charges']])
# inverse transform
train[['total_charges_inverse', 'monthly_charges_inverse']] = r_scaler.inverse_transform(train[['total_charges_scaled', 'monthly_charges_scaled']])
# visualize distributions
train[['total_charges_inverse', 'total_charges', 'monthly_charges_inverse', 'monthly_charges']].hist()
plt.tight_layout()
# view summary stats
train[['total_charges_inverse', 'total_charges', 'monthly_charges_inverse', 'monthly_charges']].describe().T
# Out:
#                           count         mean          std    min     25%  \
# total_charges_inverse    3925.0  2256.819223  2253.998263  18.85  392.65
# total_charges            3925.0  2256.819223  2253.998263  18.85  392.65
# monthly_charges_inverse  3925.0    64.722904    29.852930  18.25   37.70
# monthly_charges          3925.0    64.722904    29.852930  18.25   37.70
#
#                              50%      75%      max
# total_charges_inverse    1372.45  3729.75  8684.80
# total_charges            1372.45  3729.75  8684.80
# monthly_charges_inverse    70.15    89.70   118.75
# monthly_charges            70.15    89.70   118.75

# %% [markdown]
# ### 3. Read the documentation for sklearn's `QuantileTransformer`. Use `normal` for the `output_distribution` and apply this scaler to your data. Visualize the result of your data scaling.

# %%
# create object
scaler = sklearn.preprocessing.QuantileTransformer(output_distribution='normal')
# fit object
scaler.fit(train[['total_charges', 'monthly_charges']])
# transform object
train[['total_charges_scaled', 'monthly_charges_scaled']] = scaler.transform(train[['total_charges', 'monthly_charges']])
# visualize distributions
plt.subplot(1, 2, 1)
train.total_charges.hist()
plt.title('Before Scaling')
plt.subplot(1, 2, 2)
train.total_charges_scaled.hist()
plt.title('After Scaling')
plt.suptitle('total_charges')
plt.tight_layout();

# %%
plt.subplot(1, 2, 1)
train.monthly_charges.hist()
plt.title('Before Scaling')
plt.subplot(1, 2, 2)
train.monthly_charges_scaled.hist()
plt.title('After Scaling')
plt.suptitle('monthly_charges')
plt.tight_layout();

# %% [markdown]
# ### 4. Use the `QuantileTransformer`, but omit the `output_distribution` argument. Visualize your results.

# %%
# create object
scaler = sklearn.preprocessing.QuantileTransformer()
# fit object
scaler.fit(train[['total_charges', 'monthly_charges']])
# transform object
train[['total_charges_scaled', 'monthly_charges_scaled']] = scaler.transform(train[['total_charges', 'monthly_charges']])
# visualize distributions
plt.subplot(1, 2, 1)
train.total_charges.hist()
plt.title('Before Scaling')
plt.subplot(1, 2, 2)
train.total_charges_scaled.hist()
plt.title('After Scaling')
plt.suptitle('total_charges')
plt.tight_layout();

# %%
plt.subplot(1, 2, 1)
train.monthly_charges.hist()
plt.title('Before Scaling')
plt.subplot(1, 2, 2)
train.monthly_charges_scaled.hist()
plt.title('After Scaling')
plt.suptitle('monthly_charges')
plt.tight_layout();

# %% [markdown]
# #### What do you notice?
# I notice that the data has been scaled in such a way that the distribution is more uniform. In my opinion, it is difficult to gain much insight into the data from this output.

# %% [markdown]
# ### 5. Based on the work you've done, choose a scaling method for your dataset. Write a function within your `prepare.py` that accepts as input the train, validate, and test data splits, and returns the scaled versions of each. Be sure to only learn the parameters for scaling from your training data!
#
# After looking at the effects of different scaling methods on the telco data, I have decided I will choose the Min-Max scaling method.

# %%
def scale_telco(train, validate, test):
    mm_scaler = sklearn.preprocessing.MinMaxScaler()
    mm_scaler.fit(train[['total_charges', 'monthly_charges']])
    train[['total_charges_scaled', 'monthly_charges_scaled']] = mm_scaler.transform(train[['total_charges', 'monthly_charges']])
    validate[['total_charges_scaled', 'monthly_charges_scaled']] = mm_scaler.transform(validate[['total_charges', 'monthly_charges']])
    test[['total_charges_scaled', 'monthly_charges_scaled']] = mm_scaler.transform(test[['total_charges', 'monthly_charges']])
    return train, validate, test

# %%
# get fresh telco data
train, validate, test = prepare.wrangle_telco()
# check shapes before function
print(train.shape, validate.shape, test.shape)
# test function
train, validate, test = scale_telco(train, validate, test)
# confirm there are 2 new columns
print(train.shape, validate.shape, test.shape)
# Out:
# (3925, 32) (1683, 32) (1402, 32)
# (3925, 34) (1683, 34) (1402, 34)
