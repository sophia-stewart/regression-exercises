# %% [markdown]
# ### 7. In a separate notebook, use the functions you have developed in this exercise with the `mall_customers` dataset in the Codeup database server. You will need to write a sql query to acquire your data. Make `spending_score` your target variable.

# %%
import pandas as pd
import prepare
import explore

# %%
url = prepare.get_url('mall_customers')
sql = '''
SELECT *
FROM customers;
'''
mall = pd.read_sql(sql, url)
mall.head()
# Out:
#    customer_id  gender  age  annual_income  spending_score
# 0            1    Male   19             15              39
# 1            2    Male   21             15              81
# 2            3  Female   20             16               6
# 3            4  Female   23             16              77
# 4            5  Female   31             17              40

# %%
explore.plot_variable_pairs(mall, cols=['age', 'annual_income', 'spending_score'])

# %%
explore.plot_categorical_and_continuous_vars(mall, cat_cols=['gender'], cont_cols=['age', 'annual_income', 'spending_score'])
